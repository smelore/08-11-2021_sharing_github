# %%
import numpy as np
import pandas as pd

# %%
#read in data
gapminder = pd.read_table("gapminderDataFiveYear_superDirty.txt", sep = "\t")

# %%
#look at head and tail of df
print(gapminder.head(10))
print(gapminder.tail(5))
# Out:
#      year         pop  life Exp   gdpPercap            region
# 0  1952.0   8425333.0    28.801  779.445314  Asia_Afghanistan
# 1  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 2  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 3  1962.0  10267083.0    31.997  853.100710  Asia_Afghanistan
# 4  1962.0         NaN    31.997         NaN  Asia_Afghanistan
# 5  1967.0  11537966.0    34.020  836.197138  Asia_Afghanistan
# 6  1972.0  13079460.0    36.088  739.981106  Asia_Afghanistan
# 7  1977.0  14880372.0    38.438  786.113360  Asia_Afghanistan
# 8  1982.0  12881816.0    39.854  978.011439  Asia_Afghanistan
# 9  1987.0  13867957.0    40.822  852.395945  Asia_Afghanistan
#         year         pop  life Exp   gdpPercap           region
# 1715  1987.0   9216418.0    62.351  706.157306  Africa_Zimbabwe
# 1716  1992.0  10704340.0    60.377  693.420786  Africa_Zimbabwe
# 1717  1997.0  11404948.0    46.809  792.449960  Africa_Zimbabwe
# 1718  2002.0  11926563.0    39.989  672.038623  Africa_Zimbabwe
# 1719  2007.0  12311143.0    43.487  469.709298  Africa_Zimbabwe

# %%
#get dimensions of df
gapminder.shape
# Out:
# (1720, 5)

# %%
#gives a bit more info about df
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1720 entries, 0 to 1719
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       1717 non-null   float64
#  1   pop        1715 non-null   float64
#  2   life Exp   1719 non-null   float64
#  3   gdpPercap  1718 non-null   float64
#  4   region     1720 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 67.3+ KB

# %%
#Gives some summary statistics for numerical columns
gapminder.describe()
# Out:
#               year           pop     life Exp      gdpPercap
# count  1717.000000  1.715000e+03  1719.000000    1718.000000
# mean   1979.449039  2.954973e+07    59.436493    7208.452200
# std      17.228189  1.058366e+08    12.931041    9838.590984
# min    1952.000000  6.001100e+04    23.599000     241.165877
# 25%    1967.000000  2.807799e+06    48.143000    1203.161887
# 50%    1977.000000  7.026113e+06    60.523000    3529.585686
# 75%    1992.000000  1.959366e+07    70.840500    9322.285886
# max    2007.000000  1.318683e+09    82.603000  113523.132900

# %%
#Only look at columns we care about
my_list = ['pop', 'life Exp', 'gdpPercap']
gapminder[my_list].describe()
# Out:
#                 pop     life Exp      gdpPercap
# count  1.715000e+03  1719.000000    1718.000000
# mean   2.954973e+07    59.436493    7208.452200
# std    1.058366e+08    12.931041    9838.590984
# min    6.001100e+04    23.599000     241.165877
# 25%    2.807799e+06    48.143000    1203.161887
# 50%    7.026113e+06    60.523000    3529.585686
# 75%    1.959366e+07    70.840500    9322.285886
# max    1.318683e+09    82.603000  113523.132900

# %%
#Get specific values/ stats
print(gapminder['life Exp'].min())
print(gapminder['life Exp'].max())
print(gapminder['life Exp'].mean())
print(gapminder['life Exp'].std())
print(gapminder['life Exp'].count())
# Out:
# 23.599
# 82.603
# 59.43649312390925
# 12.931041369691727
# 1719

# %%
print(gapminder['region'].unique())
print(len(gapminder['region'].unique()))
# Out:
# ['Asia_Afghanistan' 'Europe_Albania' 'Africa_Algeria' 'Africa_Angola'
#  'Americas_Argentina' 'Oceania_Australia' 'Europe_Austria' 'Asia_Bahrain'
#  'Asia_Bangladesh' 'Europe_Belgium' 'Africa_Benin' 'Americas_Bolivia'
#  'Europe_Bosnia and Herzegovina' 'Africa_Botswana' 'Americas_Brazil'
#  'Europe_Bulgaria' 'Africa_Burkina Faso' 'Africa_Burundi' 'Asia_Cambodia'
#  'Africa_Cameroon' '_Canada' 'Americas_Canada'
#  'Africa_Central African Republic' 'Africa_Central african republic'
#  'Africa_Chad' 'Americas_Chile' 'Asia_China' 'Asia_china'
#  'Americas_Colombia' 'Americas_Colombia    ' 'Africa_Comoros'
#  'Africa_Congo, Dem. Rep.' 'Africa_Democratic Republic of the Congo'
#  'Africa_Congo, Democratic Republic' 'Africa_Congo, Rep.'
#  'Americas_Costa Rica' "Africa_Cote d'Ivoire" "Africa_Cote d'Ivore"
#  'Europe_Croatia' 'Americas_Cuba' 'Europe_Czech Republic' 'Europe_Denmark'
#  'Africa_Djibouti' 'Americas_Dominican Republic' 'Americas_Ecuador'
#  'Africa_Egypt' 'Americas_El Salvador' 'Africa_Equatorial Guinea'
#  'Africa_Eritrea' 'Africa_Ethiopia' 'Europe_Finland' 'Europe_France'
#  'Africa_Gabon' 'Africa_Gambia' 'Europe_Germany' 'Africa_Ghana'
#  'Europe_Greece' 'Americas_Guatemala' 'Africa_Guinea'
#  'Africa_Guinea-Bissau' 'Americas_Haiti' 'Americas_Honduras'
#  'Asia_Hong Kong, China' 'Europe_Hungary' 'Europe_Iceland' 'Asia_India'
#  'Asia_Indonesia' 'Asia_Iran' 'Asia_Iraq' 'Europe_Ireland' 'Asia_Israel'
#  'Europe_Italy' 'Americas_Jamaica' 'Asia_Japan' 'Asia_Jordan'
#  '    Asia_Jordan' 'Africa_Kenya' '    Asia_Korea, Dem. Rep.'
#  'Asia_Korea, Dem. Rep.' 'Asia_Korea, Rep.' 'Asia_Kuwait' 'Asia_Lebanon'
#  'Africa_Lesotho' 'Africa_Liberia' 'Africa_Libya' 'Africa_Madagascar'
#  'Africa_Malawi' 'Asia_Malaysia' 'Africa_Mali' 'Africa_Mauritania'
#  'Africa_Mauritius' 'Americas_Mexico' 'Asia_Mongolia' 'Europe_Montenegro'
#  'Africa_Morocco' 'Africa_Mozambique' 'Asia_Myanmar' 'Africa_Namibia'
#  'Asia_Nepal' 'Europe_Netherlands' 'Oceania_New Zealand'
#  'Americas_Nicaragua' 'Africa_Niger' 'Africa_Nigeria' 'Europe_Norway'
#  'Asia_Oman' 'Asia_Pakistan' 'Americas_Panama' 'Americas_Paraguay'
#  'Americas_Peru' 'Asia_Philippines' 'Europe_Poland' 'Europe_Portugal'
#  'Americas_Puerto Rico' 'Africa_Reunion' 'Europe_Romania' 'Africa_Rwanda'
#  'Africa_Sao Tome and Principe' 'Asia_Saudi Arabia' 'Africa_Senegal'
#  'Europe_Serbia' 'Africa_Sierra Leone' 'Asia_Singapore'
#  'Europe_Slovak Republic' 'Europe_Slovenia' 'Africa_Somalia'
#  'Africa_South Africa' 'Europe_Spain' 'Asia_Sri Lanka' 'Africa_Sudan'
#  'Africa_Swaziland' 'Europe_Sweden' 'Europe_Switzerland' 'Asia_Syria'
#  'Asia_Taiwan' 'Africa_Tanzania' 'Asia_Thailand' 'Africa_Togo'
#  'Americas_Trinidad and Tobago' 'Africa_Tunisia' 'Europe_Turkey'
#  'Africa_Uganda' 'Europe_United Kingdom' 'Americas_United States'
#  'Americas_Uruguay' 'Americas_Venezuela' 'Asia_Vietnam'
#  'Asia_West Bank and Gaza' 'Asia_Yemen, Rep.' 'Africa_Zambia'
#  'Africa_Zimbabwe']
# 151

# %%
print(gapminder['year'].unique())
print(gapminder['year'].value_counts())
# Out:
# [1952. 1957. 1962. 1967. 1972. 1977. 1982. 1987. 1992. 1997. 2002. 2007.
#    nan]
# 1967.0    146
# 1977.0    145
# 1982.0    144
# 1972.0    143
# 1962.0    143
# 1992.0    143
# 1957.0    143
# 1987.0    142
# 1997.0    142
# 2007.0    142
# 2002.0    142
# 1952.0    142
# Name: year, dtype: int64

# %%
#Make a copy of our original df
gapminder_copy = gapminder.copy()

# %%
#Get rid of rows containing NaN values as well as duplicate rows
print(gapminder_copy.head())
gapminder_copy =gapminder_copy.dropna()
print(gapminder_copy.head())
gapminder_copy = gapminder_copy.drop_duplicates(keep = "first")
print(gapminder_copy.head())
# Out:
#      year         pop  life Exp   gdpPercap            region
# 0  1952.0   8425333.0    28.801  779.445314  Asia_Afghanistan
# 1  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 2  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 3  1962.0  10267083.0    31.997  853.100710  Asia_Afghanistan
# 5  1967.0  11537966.0    34.020  836.197138  Asia_Afghanistan
#      year         pop  life Exp   gdpPercap            region
# 0  1952.0   8425333.0    28.801  779.445314  Asia_Afghanistan
# 1  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 3  1962.0  10267083.0    31.997  853.100710  Asia_Afghanistan
# 5  1967.0  11537966.0    34.020  836.197138  Asia_Afghanistan
# 6  1972.0  13079460.0    36.088  739.981106  Asia_Afghanistan

# %%
print(gapminder_copy.info())
gapminder_copy['year'] = gapminder_copy['year'].astype(int)
gapminder_copy['pop'] = gapminder_copy['pop'].astype(int)
print(gapminder_copy.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1704 entries, 0 to 1719
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       1704 non-null   float64
#  1   pop        1704 non-null   float64
#  2   life Exp   1704 non-null   float64
#  3   gdpPercap  1704 non-null   float64
#  4   region     1704 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 79.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1704 entries, 0 to 1719
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       1704 non-null   int64
#  1   pop        1704 non-null   int64
#  2   life Exp   1704 non-null   float64
#  3   gdpPercap  1704 non-null   float64
#  4   region     1704 non-null   object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 79.9+ KB
# None

# %%
#Need to reset index after dropping row (it was reading 0,1,3,6,...)
gapminder_copy = gapminder_copy.reset_index(drop = True)
gapminder_copy
# Out:
#       year       pop  life Exp   gdpPercap            region
# 0     1952   8425333    28.801  779.445314  Asia_Afghanistan
# 1     1957   9240934    30.332  820.853030  Asia_Afghanistan
# 2     1962  10267083    31.997  853.100710  Asia_Afghanistan
# 3     1967  11537966    34.020  836.197138  Asia_Afghanistan
# 4     1972  13079460    36.088  739.981106  Asia_Afghanistan
# ...    ...       ...       ...         ...               ...
# 1699  1987   9216418    62.351  706.157306   Africa_Zimbabwe
# 1700  1992  10704340    60.377  693.420786   Africa_Zimbabwe
# 1701  1997  11404948    46.809  792.449960   Africa_Zimbabwe
# 1702  2002  11926563    39.989  672.038623   Africa_Zimbabwe
# 1703  2007  12311143    43.487  469.709298   Africa_Zimbabwe
#
# [1704 rows x 5 columns]

# %%
#Remove whitespace from left and right sides of column, convert to all lowercase
gapminder_copy['region'] = gapminder_copy['region'].str.lstrip()
gapminder_copy['region'] = gapminder_copy['region'].str.rstrip()
gapminder_copy['region'] = gapminder_copy['region'].str.lower()
gapminder_copy
# Out:
#       year       pop  life Exp   gdpPercap            region
# 0     1952   8425333    28.801  779.445314  asia_afghanistan
# 1     1957   9240934    30.332  820.853030  asia_afghanistan
# 2     1962  10267083    31.997  853.100710  asia_afghanistan
# 3     1967  11537966    34.020  836.197138  asia_afghanistan
# 4     1972  13079460    36.088  739.981106  asia_afghanistan
# ...    ...       ...       ...         ...               ...
# 1699  1987   9216418    62.351  706.157306   africa_zimbabwe
# 1700  1992  10704340    60.377  693.420786   africa_zimbabwe
# 1701  1997  11404948    46.809  792.449960   africa_zimbabwe
# 1702  2002  11926563    39.989  672.038623   africa_zimbabwe
# 1703  2007  12311143    43.487  469.709298   africa_zimbabwe
#
# [1704 rows x 5 columns]

# %%
gapminder_copy['country'] = gapminder_copy['region'].str.split('_', 1).str[1]
gapminder_copy['continent'] = gapminder_copy['region'].str.split('_', 1).str[0]
gapminder_copy.head()
# Out:
#    year       pop  life Exp   gdpPercap            region      country  \
# 0  1952   8425333    28.801  779.445314  asia_afghanistan  afghanistan
# 1  1957   9240934    30.332  820.853030  asia_afghanistan  afghanistan
# 2  1962  10267083    31.997  853.100710  asia_afghanistan  afghanistan
# 3  1967  11537966    34.020  836.197138  asia_afghanistan  afghanistan
# 4  1972  13079460    36.088  739.981106  asia_afghanistan  afghanistan
#
#   continent
# 0      asia
# 1      asia
# 2      asia
# 3      asia
# 4      asia

# %%
gapminder_copy = gapminder_copy.drop('region', 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-6f74eeed4c53> in <module>
# ----> 1 gapminder_copy = gapminder_copy.drop('region', 1)
#       2 gapminder_copy.head()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4155                 weight  1.0     0.8
#    4156         """
# -> 4157         return super().drop(
#    4158             labels=labels,
#    4159             axis=axis,
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3910                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3911             else:
# -> 3912                 new_axis = axis.drop(labels, errors=errors)
#    3913             result = self.reindex(**{axis_name: new_axis})
#    3914
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5274         if mask.any():
#    5275             if errors != "ignore":
# -> 5276                 raise KeyError(f"{labels[mask]} not found in axis")
#    5277             indexer = indexer[~mask]
#    5278         return self.delete(indexer)
#
# KeyError: "['region'] not found in axis"

# %%
#Make column names lowercase and remove space from life exp
gapminder_copy.head()
gapminder_copy.columns = gapminder_copy.columns.str.lower()
gapminder_copy.head()
gapminder_copy = gapminder_copy.rename(columns = {'life exp' : 'lifeexp'})
gapminder_copy.head()
# Out:
#    year       pop  lifeexp   gdppercap      country continent
# 0  1952   8425333   28.801  779.445314  afghanistan      asia
# 1  1957   9240934   30.332  820.853030  afghanistan      asia
# 2  1962  10267083   31.997  853.100710  afghanistan      asia
# 3  1967  11537966   34.020  836.197138  afghanistan      asia
# 4  1972  13079460   36.088  739.981106  afghanistan      asia

# %%
PRB = pd.read_table("PRB_data.txt", sep = "\t")

# %%
PRB.head()
PRB['country'] = PRB['region'].str.split('_', 1).str[1].str.lower()
PRB['continent'] = PRB['region'].str.split('_', 1).str[0].str.lower()
PRB = PRB.drop('region', 1)
PRB.head()
# Out:
#    year     pop  lifeExp  gdpPercap                       country continent
# 0  1952  113805    66.75   779.6780  peoples republic of berkeley  americas
# 1  1957  114077    67.96   821.2960  peoples republic of berkeley  americas
# 2  1962  111268    71.11   857.2354  peoples republic of berkeley  americas
# 3  1967  114785    72.03   838.1382  peoples republic of berkeley  americas
# 4  1972  116716    72.67   737.1058  peoples republic of berkeley  americas

# %%
PRB.columns = PRB.columns.str.lower()
PRB = PRB.rename(columns={'life exp' : 'lifeexp'})
PRB.head()
# Out:
#    year     pop  lifeexp  gdppercap                       country continent
# 0  1952  113805    66.75   779.6780  peoples republic of berkeley  americas
# 1  1957  114077    67.96   821.2960  peoples republic of berkeley  americas
# 2  1962  111268    71.11   857.2354  peoples republic of berkeley  americas
# 3  1967  114785    72.03   838.1382  peoples republic of berkeley  americas
# 4  1972  116716    72.67   737.1058  peoples republic of berkeley  americas

# %%
gapminder_copy.head()
gapminder_comb = pd.concat([gapminder_copy, PRB])

# %%
#Need to reset index after concatenating since it keeps the indices from original datasets
gapminder_comb = gapminder_comb.reset_index(drop = True)
gapminder_comb
# Out:
#       year       pop  lifeexp   gdppercap                       country  \
# 0     1952   8425333   28.801  779.445314                   afghanistan
# 1     1957   9240934   30.332  820.853030                   afghanistan
# 2     1962  10267083   31.997  853.100710                   afghanistan
# 3     1967  11537966   34.020  836.197138                   afghanistan
# 4     1972  13079460   36.088  739.981106                   afghanistan
# ...    ...       ...      ...         ...                           ...
# 1711  1987    102351   75.960  851.944800  peoples republic of berkeley
# 1712  1992    103328   76.950  649.395200  peoples republic of berkeley
# 1713  1997    102724   78.910  636.343500  peoples republic of berkeley
# 1714  2002    102743   79.070  726.734000  peoples republic of berkeley
# 1715  2007    112580   80.030  979.338400  peoples republic of berkeley
#
#      continent
# 0         asia
# 1         asia
# 2         asia
# 3         asia
# 4         asia
# ...        ...
# 1711  americas
# 1712  americas
# 1713  americas
# 1714  americas
# 1715  americas
#
# [1716 rows x 6 columns]

# %%
gapminder_copy[0:15]
#Same as:
gapminder_copy[:15]
#get a specific column or get certain rows from a df by filtering on a column
gapminder_copy['year']
gapminder_africa = gapminder_copy[gapminder_copy['continent'] == 'africa']
#sort df based on values in a column
sorted_africa = gapminder_africa.sort_values(by = ['year', 'country'], ascending = [False, True])
sorted_africa.head()
# Out:
#      year       pop  lifeexp     gdppercap       country continent
# 35   2007  33333216   72.301   6223.367465       algeria    africa
# 47   2007  12420476   42.731   4797.231267        angola    africa
# 131  2007   8078314   56.728   1441.284873         benin    africa
# 167  2007   1639131   50.728  12569.851770      botswana    africa
# 203  2007  14326203   52.295   1217.032994  burkina faso    africa

# %%
print(gapminder_comb.info())
stat_list = ['pop', 'lifeexp', 'gdppercap']
gapminder_comb[stat_list].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1716 entries, 0 to 1715
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       1716 non-null   int64
#  1   pop        1716 non-null   int64
#  2   lifeexp    1716 non-null   float64
#  3   gdppercap  1716 non-null   float64
#  4   country    1716 non-null   object
#  5   continent  1716 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.6+ KB
# None
#                 pop      lifeexp      gdppercap
# count  1.716000e+03  1716.000000    1716.000000
# mean   2.939498e+07    59.577013    7170.489352
# std    1.058144e+08    12.934328    9837.440250
# min    6.001100e+04    23.599000     241.165877
# 25%    2.735858e+06    48.275750    1177.869539
# 50%    6.985493e+06    60.873500    3484.113173
# 75%    1.929230e+07    70.961000    9279.348034
# max    1.318683e+09    82.603000  113523.132900

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#histogram 
plt.hist(gapminder_copy['lifeexp'])
plt.xlabel('Life Expectancy')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#boxplot
sns.boxplot(x = 'year', y = 'lifeexp', data = gapminder_copy)
plt.xlabel('year')
plt.ylabel('life expectancy')
# Out:
# Text(0, 0.5, 'life expectancy')

# %%
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/smelore/opt/miniconda3
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     patsy-0.5.1                |             py_0         187 KB  conda-forge
#     seaborn-0.11.1             |       hd8ed1ab_1           4 KB  conda-forge
#     seaborn-base-0.11.1        |     pyhd8ed1ab_1         217 KB  conda-forge
#     statsmodels-0.12.2         |   py38ha1b04c9_0        10.5 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        10.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   patsy              conda-forge/noarch::patsy-0.5.1-py_0
#   seaborn            conda-forge/noarch::seaborn-0.11.1-hd8ed1ab_1
#   seaborn-base       conda-forge/noarch::seaborn-base-0.11.1-pyhd8ed1ab_1
#   statsmodels        conda-forge/osx-64::statsmodels-0.12.2-py38ha1b04c9_0
#
#
#
# Downloading and Extracting Packages
# seaborn-0.11.1       | 4 KB      | ##################################### | 100%
# statsmodels-0.12.2   | 10.5 MB   | ##################################### | 100%
# seaborn-base-0.11.1  | 217 KB    | ##################################### | 100%
# patsy-0.5.1          | 187 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.scatter(gapminder_copy['gdppercap'], gapminder_copy['lifeexp'])
plt.xlabel("GDP Per Capita")
plt.ylabel('life expectancy')
# Out:
# Text(0, 0.5, 'life expectancy')

# %%
plt.scatter(gapminder_copy['gdppercap'], gapminder_copy['lifeexp'])
plt.xlabel("GDP Per Capita (log)")
plt.ylabel('life expectancy')
plt.xscale('log')

plt.savefig("logscale_scatter_plot.png")

# %%
#Regex, https://regex101.com/
print(gapminder[gapminder['region'].str.contains('Congo')])
gapminder['region'].replace(".*Congo, Dem.*", "africa_dem rep congo", regex = True, inplace = True)
gapminder['region'].replace(".*Democratic Republic of the Congo", "africa_dem rep congo", regex = True, inplace = True)
print(gapminder[gapminder['region'].str.contains('congo')])
# Out:
#        year         pop  life Exp   gdpPercap                region
# 333  1952.0  14100005.0    39.143  780.542326  africa_dem rep congo
# 334  1957.0  15577932.0    40.652  905.860230  africa_dem rep congo
# 335  1962.0  17486434.0    42.122  896.314634  africa_dem rep congo
# 336  1967.0  19941073.0    44.056  861.593242  africa_dem rep congo
# 337  1972.0  23007669.0    45.989  904.896069  africa_dem rep congo
# 338  1977.0  26480870.0    47.804  795.757282  africa_dem rep congo
# 339  1982.0  30646495.0    47.784  673.747818  africa_dem rep congo
# 340  1987.0  35481645.0    47.412  672.774812  africa_dem rep congo
# 341  1992.0  41672143.0    45.548  457.719181  africa_dem rep congo
# 342  1997.0  47798986.0    42.587  312.188423  africa_dem rep congo
# 343  2002.0  55379852.0    44.966  241.165877  africa_dem rep congo
# 344  2007.0  64606759.0    46.462  277.551859  africa_dem rep congo
#        year         pop  life Exp   gdpPercap                region
# 333  1952.0  14100005.0    39.143  780.542326  africa_dem rep congo
# 334  1957.0  15577932.0    40.652  905.860230  africa_dem rep congo
# 335  1962.0  17486434.0    42.122  896.314634  africa_dem rep congo
# 336  1967.0  19941073.0    44.056  861.593242  africa_dem rep congo
# 337  1972.0  23007669.0    45.989  904.896069  africa_dem rep congo
# 338  1977.0  26480870.0    47.804  795.757282  africa_dem rep congo
# 339  1982.0  30646495.0    47.784  673.747818  africa_dem rep congo
# 340  1987.0  35481645.0    47.412  672.774812  africa_dem rep congo
# 341  1992.0  41672143.0    45.548  457.719181  africa_dem rep congo
# 342  1997.0  47798986.0    42.587  312.188423  africa_dem rep congo
# 343  2002.0  55379852.0    44.966  241.165877  africa_dem rep congo
# 344  2007.0  64606759.0    46.462  277.551859  africa_dem rep congo

# %%
# Out:
# africa_dem rep congo           24
# Europe_Netherlands             15
# Asia_Afghanistan               14
# Americas_Bolivia               14
# Americas_Dominican Republic    14
#                                ..
# _Canada                         3
#     Asia_Korea, Dem. Rep.       2
# Americas_Colombia               2
#     Asia_Jordan                 1
# Africa_Cote d'Ivore             1
# Name: region, Length: 148, dtype: int64
